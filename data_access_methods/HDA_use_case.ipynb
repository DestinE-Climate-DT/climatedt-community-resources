# %% [markdown]
# #### HDA simplified use case
# Within ClimateDT, HDA is generally used to access the output data of the [impact-sector applications](https://platform.destine.eu/docs/climate-dt-user-guide/doc/apps/index.html). Find may find a list of jupyter notebooks examples for each application [here](https://github.com/DestinE-Climate-DT/climatedt-community-resources/tree/main/example_apps).
#
# As the examples are carefelly explained under the same project, we did not include any example at the moment.
